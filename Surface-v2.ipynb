# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.sparse import hstack
import numpy as np
import pickle

# %%
statead = pd.read_csv('./statead.csv')
test = pd.read_csv('./pre/test.csv')
statead.head()
# Out:
#    creativenessID  brand  successclick\n  successconversion
# 0            4079    191          2890.0                 10
# 1            4565     56        449000.0              11622
# 2            3170   1400           387.0                  5
# 3            6566   1400           224.0                  1
# 4            5187     56        141000.0               2277

# %%
train = pd.read_csv('./pre/train.csv')
train.head()
# Out:
#    label  clickTime  conversionTime  creativeID   userID  positionID  \
# 0      0     170000             NaN        3089  2798058         293
# 1      0     170000             NaN        1259   463234        6161
# 2      0     170000             NaN        4465  1857485        7434
# 3      0     170000             NaN        1004  2038823         977
# 4      0     170000             NaN        1887  2015141        3688
#
#    connectionType  telecomsOperator
# 0               1                 1
# 1               1                 2
# 2               4                 1
# 3               1                 1
# 4               1                 1

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

import scipy.io
import pandas

mat = scipy.io.loadmat('./pre/train_clear.mat')
print mat
mat = mat['clear_train_DATA']
frm = pandas.DataFrame(mat)
frm.to_csv('./pre/train_clear.csv')
# Out:
# {'__version__': '1.0', 'clear_train_DATA': array([[     0, 170000,      0, ...,    293,      1,      1],
#        [     0, 170000,      0, ...,   6161,      1,      2],
#        [     0, 170000,      0, ...,   7434,      4,      1],
#        ...,
#        [     0, 302359,      0, ...,   6315,      1,      1],
#        [     0, 302359,      0, ...,   7149,      1,      1],
#        [     0, 302359,      0, ...,   1463,      1,      1]]), '__header__': 'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Thu Jun 01 21:40:41 2017', '__globals__': []}

# %%
train = pd.read_csv('./pre/train_clear.csv')

train.rename(columns={'0':'label', '1':'clickTime', '2':'conversionTime', '3':'creativeID', '4':'userID', '5':'positionID', '6':'connectionType', '7':'telecomsOperator'}, inplace = True)
# Out:
#          Unnamed: 0  label  clickTime  conversionTime  creativeID   userID  \
# 0                 0      0     170000               0        3089  2798058
# 1                 1      0     170000               0        1259   463234
# 2                 2      0     170000               0        4465  1857485
# 3                 3      0     170000               0        1004  2038823
# 4                 4      0     170000               0        1887  2015141
# 5                 5      0     170000               0        3293  1177829
# 6                 6      0     170000               0        4793  1257450
# 7                 7      0     170000               0        1456   764204
# 8                 8      0     170000               0        4465  1438585
# 9                 9      0     170000               0         985  1750317
# 10               10      0     170000               0        3465  2079582
# ...

# %%
del train['Unnamed: 0']
train.head()
# Out:
#    label  clickTime  conversionTime  creativeID   userID  positionID  \
# 0      0     170000               0        3089  2798058         293
# 1      0     170000               0        1259   463234        6161
# 2      0     170000               0        4465  1857485        7434
# 3      0     170000               0        1004  2038823         977
# 4      0     170000               0        1887  2015141        3688
#
#    connectionType  telecomsOperator
# 0               1                 1
# 1               1                 2
# 2               4                 1
# 3               1                 1
# 4               1                 1

# %%
train.to_csv('./pre/train_clear.csv',index=None)

# %%
train = pd.read_csv('./pre/train_clear.csv')

# %%
train.isnull().values.any()
# Out:
# False
